# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/2021_Formula_One_World_Championship'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>2021 Formula One World Championship - Wikipedia</title>
# ...

# %%
tables = pd.read_html(url)

# %%
f1Table = tables[2]

# %%
f1Table
# Out:
#                    Round                 Grand Prix  \
# 0                      1         Bahrain Grand Prix
# 1                      2  Emilia Romagna Grand Prix
# 2                      3                        TBA
# 3                      4         Spanish Grand Prix
# 4                      5          Monaco Grand Prix
# 5                      6      Azerbaijan Grand Prix
# 6                      7        Canadian Grand Prix
# 7                      8          French Grand Prix
# 8                      9        Austrian Grand Prix
# 9                     10         British Grand Prix
# 10                    11       Hungarian Grand Prix
# 11                    12         Belgian Grand Prix
# 12                    13           Dutch Grand Prix
# 13                    14         Italian Grand Prix
# 14                    15         Russian Grand Prix
# 15                    16       Singapore Grand Prix
# 16                    17        Japanese Grand Prix
# ...

# %%
f1Table2 = tables[1]

# %%
f1Table2
# Out:
#                                               Entrant  \
# 0                             Alfa Romeo Racing Orlen
# 1                             Alfa Romeo Racing Orlen
# 2                           Scuderia AlphaTauri Honda
# 3                           Scuderia AlphaTauri Honda
# 4                                  Alpine F1 Team[14]
# 5                                  Alpine F1 Team[14]
# 6   Aston Martin Cognizant Formula One Team[18][19...
# 7   Aston Martin Cognizant Formula One Team[18][19...
# 8                     Scuderia Ferrari Mission Winnow
# 9                     Scuderia Ferrari Mission Winnow
# 10                                       Haas F1 Team
# 11                                       Haas F1 Team
# 12                                    McLaren F1 Team
# 13                                    McLaren F1 Team
# 14             Mercedes-AMG Petronas Formula One Team
# 15             Mercedes-AMG Petronas Formula One Team
# ...

# %%
f1Table2.to_csv('/Users/christinemagnotta/f1team.csv', index=False)

# %%
f1Table.to_csv('/Users/christinemagnotta/f1calender.csv', index=False)

# %%
list(f1Table2.columns)
# Out:
# ['Entrant',
#  'Constructor[6]',
#  'Chassis',
#  'Power unit',
#  'No.',
#  'Driver name',
#  'Ref.']

# %%
f1Table2.drop('Power unit', axis=1, inplace=True)

# %%
f1Table2.drop('Ref.', axis=1, inplace=True)

# %%
f1Table2.drop('Chassis', axis=1, inplace=True)

# %%
f1Table2
# Out:
#                                               Entrant  \
# 0                             Alfa Romeo Racing Orlen
# 1                             Alfa Romeo Racing Orlen
# 2                           Scuderia AlphaTauri Honda
# 3                           Scuderia AlphaTauri Honda
# 4                                  Alpine F1 Team[14]
# 5                                  Alpine F1 Team[14]
# 6   Aston Martin Cognizant Formula One Team[18][19...
# 7   Aston Martin Cognizant Formula One Team[18][19...
# 8                     Scuderia Ferrari Mission Winnow
# 9                     Scuderia Ferrari Mission Winnow
# 10                                       Haas F1 Team
# 11                                       Haas F1 Team
# 12                                    McLaren F1 Team
# 13                                    McLaren F1 Team
# 14             Mercedes-AMG Petronas Formula One Team
# 15             Mercedes-AMG Petronas Formula One Team
# ...

# %%
f1Table2clean = f1Table2.drop([20])

# %%
f1Table2clean
# Out:
#                                               Entrant  \
# 0                             Alfa Romeo Racing Orlen
# 1                             Alfa Romeo Racing Orlen
# 2                           Scuderia AlphaTauri Honda
# 3                           Scuderia AlphaTauri Honda
# 4                                  Alpine F1 Team[14]
# 5                                  Alpine F1 Team[14]
# 6   Aston Martin Cognizant Formula One Team[18][19...
# 7   Aston Martin Cognizant Formula One Team[18][19...
# 8                     Scuderia Ferrari Mission Winnow
# 9                     Scuderia Ferrari Mission Winnow
# 10                                       Haas F1 Team
# 11                                       Haas F1 Team
# 12                                    McLaren F1 Team
# 13                                    McLaren F1 Team
# 14             Mercedes-AMG Petronas Formula One Team
# 15             Mercedes-AMG Petronas Formula One Team
# ...

# %%
f1Table2clean.to_csv('/Users/christinemagnotta/f1team.csv', index=False)

# %%
f1Table
# Out:
#                    Round                 Grand Prix  \
# 0                      1         Bahrain Grand Prix
# 1                      2  Emilia Romagna Grand Prix
# 2                      3                        TBA
# 3                      4         Spanish Grand Prix
# 4                      5          Monaco Grand Prix
# 5                      6      Azerbaijan Grand Prix
# 6                      7        Canadian Grand Prix
# 7                      8          French Grand Prix
# 8                      9        Austrian Grand Prix
# 9                     10         British Grand Prix
# 10                    11       Hungarian Grand Prix
# 11                    12         Belgian Grand Prix
# 12                    13           Dutch Grand Prix
# 13                    14         Italian Grand Prix
# 14                    15         Russian Grand Prix
# 15                    16       Singapore Grand Prix
# 16                    17        Japanese Grand Prix
# ...

# %%
f1calendar = f1Table.drop([23])

# %%
f1calendar
# Out:
#    Round                 Grand Prix  \
# 0      1         Bahrain Grand Prix
# 1      2  Emilia Romagna Grand Prix
# 2      3                        TBA
# 3      4         Spanish Grand Prix
# 4      5          Monaco Grand Prix
# 5      6      Azerbaijan Grand Prix
# 6      7        Canadian Grand Prix
# 7      8          French Grand Prix
# 8      9        Austrian Grand Prix
# 9     10         British Grand Prix
# 10    11       Hungarian Grand Prix
# 11    12         Belgian Grand Prix
# 12    13           Dutch Grand Prix
# 13    14         Italian Grand Prix
# 14    15         Russian Grand Prix
# 15    16       Singapore Grand Prix
# 16    17        Japanese Grand Prix
# 17    18   United States Grand Prix
# 18    19     Mexico City Grand Prix
# 19    20    São Paulo Grand Prix[c]
# 20    21      Australian Grand Prix
# 21    22   Saudi Arabian Grand Prix
# 22    23       Abu Dhabi Grand Prix
#
#                                               Circuit       Race date
# ...

# %%
f1calendar.to_csv('/Users/christinemagnotta/f1callendar.csv', index=False)
